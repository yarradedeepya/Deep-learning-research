# %%
import mne

# Download and load the sample dataset
mne.set_config('MNE_DATASETS_DIR', 'C:/Users/Dedu/mne_data')
mne.datasets.sample.data_path(verbose=True)
raw_fname = str(mne.datasets.sample.data_path()) + '/MEG/sample/sample_audvis_raw.fif'
raw = mne.io.read_raw_fif(raw_fname, preload=True)

#mne.datasets.fetch_hcp_mmp_parcellation(subjects_dir='/path/to/subjects_dir', verbose=True)
fwd_fname = str(mne.datasets.sample.data_path()) + '/MEG/sample/sample_audvis-meg-eeg-oct-6-fwd.fif'
# Out:
# C:\Users\Dedu\AppData\Local\Temp\ipykernel_11732\3405524519.py:4: RuntimeWarning: Setting non-standard config type: "MNE_DATASETS_DIR"
#   mne.set_config('MNE_DATASETS_DIR', 'C:/Users/Dedu/mne_data')
# C:\Users\Dedu\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# Opening raw data file C:\Users\Dedu\mne_data\MNE-sample-data/MEG/sample/sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# Reading 0 ... 166799  =      0.000 ...   277.714 secs...

# %%
mne.utils.set_config('SUBJECTS_DIR', 'C:/Users/Dedu/mne_data/MNE-fsaverage-data', set_env=True)

fs_dir = mne.datasets.fetch_fsaverage(verbose=True)
print(fs_dir)
# Out:
# 0 files missing from root.txt in C:\Users\Dedu\mne_data\MNE-fsaverage-data
# 0 files missing from bem.txt in C:\Users\Dedu\mne_data\MNE-fsaverage-data\fsaverage
# C:\Users\Dedu\mne_data\MNE-fsaverage-data\fsaverage

# %%
raw.info ['bads'] = ['MEG 2443', 'EEG 053'] #mark bad channels
# low-pass filter data
raw.filter (l_freq=None, h_freq=40.0)
raw.set_eeg_reference('average', projection=True)

# extract epochs and save them
picks = mne.pick_types (raw.info, meg=True, eeg=True, eog=True,exclude='bads')
events = mne.find_events (raw)
epochs = mne.Epochs(raw, events, event_id=1, tmin=-0.2, tmax=0.5, proj=True, picks=picks, baseline=(None, 0), preload=True, reject=dict(grad=4000e-13, mag=4e-12, eog=150e-6))

# compute evoked response and noise covariance,and plot evoked
evoked = epochs.average ()

cov = mne.compute_covariance (epochs, tmax=0)
evoked.plot ()
# compute inverse operator
#fwd_fname = 'sample_audvis−meg−eeg−oct−6−fwd.fif'
raw.set_eeg_reference(projection=True)
fwd = mne.read_forward_solution(fwd_fname)
inv = mne.minimum_norm.make_inverse_operator(raw.info, fwd, cov, loose=0.2)
# compute inverse solution
stc = mne.minimum_norm.apply_inverse(evoked, inv, lambda2=1./9., method='dSPM')
# morph it to average brain for group study and plot it
#stc_avg = mne.morph_data ('sample', 'fsaverage', stc, 5, smooth=5)
morph = mne.compute_source_morph(src=inv['src'], subject_from='sample', subject_to='fsaverage', spacing=5, smooth=5)
stc_avg = morph.apply(stc)
stc_avg.plot ()
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 199 samples (0.331 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# 320 events found
# Event IDs: [ 1  2  3  4  5 32]
# Not setting metadata
# 72 matching events found
# Setting baseline interval to [-0.19979521315838786, 0.0] sec
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 4)
# 4 projection items activated
# Using data from preloaded Raw for 72 events and 421 original time points ...
# [Parallel(n_jobs=1)]: Done 366 out of 366 | elapsed:    1.5s finished
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on MAG : ['MEG 1711']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
#     Rejecting  epoch based on EOG : ['EOG 061']
# 17 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 5.6e-09 (2.2e-16 eps * 305 dim * 8.2e+04  max singular value)
#     Estimated rank (mag + grad): 302
#     MEG: rank 302 computed from 305 data channels with 3 projectors
#     Using tolerance 2.2e-11 (2.2e-16 eps * 59 dim * 1.7e+03  max singular value)
#     Estimated rank (eeg): 58
#     EEG: rank 58 computed from 59 data channels with 1 projector
#     Created an SSP operator (subspace dimension = 4)
#     Setting small MEG eigenvalues to zero (without PCA)
#     Setting small EEG eigenvalues to zero (without PCA)
# Reducing data rank from 364 -> 360
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 6655
# [done]
# EEG channel type selected for re-referencing
# Reading forward solution from C:\Users\Dedu\mne_data\MNE-sample-data\MEG\sample\sample_audvis-meg-eeg-oct-6-fwd.fif...
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Desired named matrix (kind = 3523) not available
#     Read MEG forward solution (7498 sources, 306 channels, free orientations)
#     Desired named matrix (kind = 3523) not available
#     Read EEG forward solution (7498 sources, 60 channels, free orientations)
#     Forward solutions combined: MEG, EEG
#     Source spaces transformed to the forward solution coordinate frame
# C:\Users\Dedu\AppData\Local\Temp\ipykernel_11732\146866549.py:18: RuntimeWarning: An average reference projection was already added. The data has been left untouched.
#   raw.set_eeg_reference(projection=True)
# Converting forward solution to surface orientation
#     Average patch normals will be employed in the rotation to the local surface coordinates....
#     Converting to surface-based source orientations...
#     [done]
# info["bads"] and noise_cov["bads"] do not match, excluding bad channels from both
# Computing inverse operator with 364 channels.
#     364 out of 366 channels remain after picking
# Selected 364 channels
# Creating the depth weighting matrix...
#     203 planar channels
#     limit = 7262/7498 = 10.020865
#     scale = 2.58122e-08 exp = 0.8
# Applying loose dipole orientations to surface source spaces: 0.2
# Whitening the forward solution.
#     Created an SSP operator (subspace dimension = 4)
# Computing rank from covariance with rank=None
#     Using tolerance 2.9e-13 (2.2e-16 eps * 305 dim * 4.3  max singular value)
#     Estimated rank (mag + grad): 302
#     MEG: rank 302 computed from 305 data channels with 3 projectors
#     Using tolerance 5.6e-14 (2.2e-16 eps * 59 dim * 4.3  max singular value)
#     Estimated rank (eeg): 58
#     EEG: rank 58 computed from 59 data channels with 1 projector
#     Setting small MEG eigenvalues to zero (without PCA)
#     Setting small EEG eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing SVD of whitened and weighted lead field matrix.
#     largest singular value = 5.16169
#     scaling factor to adjust the trace = 1.87532e+19 (nchan = 364 nzero = 4)
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 55
#     Created the regularized inverter
#     Created an SSP operator (subspace dimension = 4)
#     Created the whitener using a noise covariance matrix with rank 360 (4 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 364 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  65.9% variance
#     Combining the current components...
#     dSPM...
# [done]
# surface source space present ...
# Computing morph matrix...
#     Left-hemisphere map read.
#     Right-hemisphere map read.
#     5 smooth iterations done.
#     5 smooth iterations done.
# [done]
# [done]
# C:\Users\Dedu\AppData\Local\Temp\ipykernel_11732\146866549.py:25: RuntimeWarning: 19816/163842 vertices not included in smoothing, consider increasing the number of steps
#   morph = mne.compute_source_morph(src=inv['src'], subject_from='sample', subject_to='fsaverage', spacing=5, smooth=5)
# C:\Users\Dedu\AppData\Local\Temp\ipykernel_11732\146866549.py:25: RuntimeWarning: 18238/163842 vertices not included in smoothing, consider increasing the number of steps
#   morph = mne.compute_source_morph(src=inv['src'], subject_from='sample', subject_to='fsaverage', spacing=5, smooth=5)
# Using pyvistaqt 3d backend.
#
# Using control points [ 3.78588955  4.36816359 14.1338888 ]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`

# %%
import mne
from mne.datasets import sample
import numpy as np
# Setup paths and prepare data
raw_fname = str(sample.data_path ()) + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
raw = mne.io.Raw (raw_fname, preload=True)
picks = mne.pick_types (raw.info, meg='mag', exclude='bads')
ica = mne.preprocessing.ICA (n_components=49)
ica.fit(raw, picks=picks, decim=3) # use every third sample
# find artifacts using bivariate and univariate measures
eog_indices, eog_scores = ica.find_bads_eog(raw, ch_name='EOG 061')
ica.exclude += eog_indices

#scores = ica.find_sources_raw (raw, score_func=np.var)
#ica.exclude += [eog_scores.argmax ()]

# Visualize result using topography and source time course
#mne.viz.plot_topomap(ica.get_components()[ica.exclude], ica.info)

ica.plot_sources(raw, ica.exclude, start=100., stop=103.)
ica.plot_overlay(raw)
# Out:
# Opening raw data file C:\Users\Dedu\mne_data\MNE-sample-data/MEG/sample/sample_audvis_filt-0-40_raw.fif...
#     Read a total of 4 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#         Average EEG reference (1 x 60)  idle
#     Range : 6450 ... 48149 =     42.956 ...   320.665 secs
# Ready.
# Reading 0 ... 41699  =      0.000 ...   277.709 secs...
# Fitting ICA to data using 102 channels (please be patient, this may take a while)
# Selecting by number: 49 components
# Fitting ICA took 1.6s.
# Using EOG channel: EOG 061
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1502 samples (10.003 sec)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1502 samples (10.003 sec)
#
# Creating RawArray with float64 data, n_channels=2, n_times=41700
#     Range : 6450 ... 48149 =     42.956 ...   320.665 secs
# Ready.
# Using matplotlib as 2D backend.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Applying ICA to Raw instance
#     Transforming to ICA space (49 components)
#     Zeroing out 1 ICA component
#     Projecting back using 102 PCA components

# %%
import mne
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, ShuffleSplit
# Take only the data channels (here the gradiometers)
epochs1 = epochs['1']
epochs2 = epochs['1']
data_picks = mne.pick_types (epochs1.info, meg='grad', exclude='bads')
# Make arrays X and y such that:
# X is 3d with X.shape[0] is the total number of epochs to classify
# y is filled with integers coding for the class to predict
# We must have X.shape[0] equal to y.shape[0]

X = [e.get_data () [:, data_picks, :] for e in (epochs1, epochs2)]
y = [k * np.ones (len(this_X)) for k, this_X in enumerate(X)]
X = np. concatenate (X)
y = np. concatenate (y)
clf = SVC(C=1, kernel='linear')
# Define a monte-carlo cross-validation generator (to reduce variance):
cv = ShuffleSplit (len(X), test_size=0.2)
scores, std_scores = np.empty (X.shape[2]), np.empty (X.shape[2])
for t in range(X.shape[2]):
    Xt = X[:, :, t]
    scores_t = cross_val_score(clf, Xt, y, cv=cv, n_jobs=1)
    scores [t] = scores_t.mean ()
    std_scores [t] = scores_t.std ()

# %%
from mne.minimum_norm import apply_inverse_epochs
#from mne_connectivity import spectral_connectivity
from mne_connectivity import spectral_connectivity_epochs
from mne import read_labels_from_annot
from mne import extract_label_time_course
snr = 3.0  # signal-to-noise ratio
lambda2 = 1.0 / snr ** 2  # regularization parameter

# Apply inverse to single epochs
stcs = apply_inverse_epochs(epochs, inv, lambda2, method='dSPM', pick_ori='normal', return_generator=True)

# Summarize source estimates in labels
subdir='C:/Users/Dedu/mne_data/MNE-sample-data/subjects'
print(subdir)
labels = read_labels_from_annot('sample', parc='aparc', subjects_dir=subdir)
label_ts = extract_label_time_course(stcs, labels, inv['src'], mode='mean_flip', return_generator=True)

# Compute all-to-all connectivity between labels
con = spectral_connectivity_epochs(label_ts, method='wpli2_debiased', mode='multitaper', sfreq=raw.info['sfreq'], fmin=8., fmax=13., faverage=True, mt_adaptive=True)
freqs = con.freqs
# Out:
# C:/Users/Dedu/mne_data/MNE-sample-data/subjects
# Reading labels from parcellation...
#    read 34 labels from C:\Users\Dedu\mne_data\MNE-sample-data\subjects\sample\label\lh.aparc.annot
#    read 34 labels from C:\Users\Dedu\mne_data\MNE-sample-data\subjects\sample\label\rh.aparc.annot
# Connectivity computation...
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 1
#     Created the regularized inverter
#     Created an SSP operator (subspace dimension = 4)
#     Created the whitener using a noise covariance matrix with rank 360 (4 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Picked 364 channels from the data
# Computing inverse...
#     Eigenleads need to be weighted ...
# Processing epoch : 1 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
# only using indices for lower-triangular matrix
#     computing connectivity for 2278 connections
#     using t=0.000s..2.797s for estimation (421 points)
#     frequencies: 8.2Hz..12.8Hz (14 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
# Processing epoch : 2 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 2
# Processing epoch : 3 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 3
# Processing epoch : 4 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 4
# Processing epoch : 5 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 5
# Processing epoch : 6 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 6
# Processing epoch : 7 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 7
# Processing epoch : 8 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 8
# Processing epoch : 9 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 9
# Processing epoch : 10 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 10
# Processing epoch : 11 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 11
# Processing epoch : 12 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 12
# Processing epoch : 13 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 13
# Processing epoch : 14 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 14
# Processing epoch : 15 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 15
# Processing epoch : 16 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 16
# Processing epoch : 17 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 17
# Processing epoch : 18 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 18
# Processing epoch : 19 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 19
# Processing epoch : 20 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 20
# Processing epoch : 21 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 21
# Processing epoch : 22 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 22
# Processing epoch : 23 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 23
# Processing epoch : 24 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 24
# Processing epoch : 25 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 25
# Processing epoch : 26 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 26
# Processing epoch : 27 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 27
# Processing epoch : 28 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 28
# Processing epoch : 29 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 29
# Processing epoch : 30 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 30
# Processing epoch : 31 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 31
# Processing epoch : 32 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 32
# Processing epoch : 33 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 33
# Processing epoch : 34 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 34
# Processing epoch : 35 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 35
# Processing epoch : 36 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 36
# Processing epoch : 37 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 37
# Processing epoch : 38 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 38
# Processing epoch : 39 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 39
# Processing epoch : 40 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 40
# Processing epoch : 41 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 41
# Processing epoch : 42 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 42
# Processing epoch : 43 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 43
# Processing epoch : 44 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 44
# Processing epoch : 45 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 45
# Processing epoch : 46 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 46
# Processing epoch : 47 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 47
# Processing epoch : 48 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 48
# Processing epoch : 49 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 49
# Processing epoch : 50 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 50
# Processing epoch : 51 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 51
# Processing epoch : 52 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 52
# Processing epoch : 53 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 53
# Processing epoch : 54 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 54
# Processing epoch : 55 / 55
# Extracting time courses for 68 labels (mode: mean_flip)
#     computing connectivity for epoch 55
# [done]
#     assembling connectivity matrix
# [Connectivity computation done]

# %%
import mne
# load raw data and create epochs and evoked objects as in Table 1, but picking
# only MEG channels using mne.fiff.pick_types(raw.info, meg=True, eeg=False)
# compute noise and data covariance
picks = mne.pick_types (raw.info, meg='mag', eeg=False, eog=False, exclude='bads')
events = mne.find_events (raw)
epochs = mne.Epochs(raw, events, event_id=1, tmin=-0.2, tmax=0.5, proj=True, picks=picks, baseline=(None, 0), preload=True, reject=dict(mag=4e-12))

#compute evoked response and noise covariance
evoked = epochs.average ()

noise_cov = mne.compute_covariance(epochs, tmax=0.0,)
#noise_cov = mne.compute_covariance(epochs, tmax=0.0, method='empirical', meg=True)
noise_cov = mne.cov.regularize (noise_cov, evoked.info, mag=0.05, grad=0.05, proj=True)
data_cov = mne.compute_covariance (epochs, tmin=0.04, tmax=0.15)
# compute LCMV inverse solution
fwd_fname = str(mne.datasets.sample.data_path()) + '/MEG/sample/sample_audvis-meg-vol-7-fwd.fif'
#fwd_fname = 'sample_audvis−meg−vol−7−fwd.fif'
fwd = mne.read_forward_solution (fwd_fname)
stc = mne.beamformer.make_lcmv(evoked.info, fwd, noise_cov, reg=0.1, pick_ori='max-power')
# save result in 4D nifti file for plotting with Freesurfer
#stc_vol = stc.apply(evoked.copy().pick_types(meg='mag'))
stc.save('lcmv.nii.gz', overwrite=True)
#stc.save_as_volume('lcmv.nii.gz', fwd['src'], mri_resolution=False)
# Out:
# 319 events found
# Event IDs: [ 1  2  3  4  5 32]
# Not setting metadata
# 72 matching events found
# Setting baseline interval to [-0.19979521315838786, 0.0] sec
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 3)
# 4 projection items activated
# Using data from preloaded Raw for 72 events and 106 original time points ...
#     Rejecting  epoch based on MAG : ['MEG 1711']
# 1 bad epochs dropped
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 60>
# Computing rank from data with rank=None
#     Using tolerance 1e-09 (2.2e-16 eps * 102 dim * 4.6e+04  max singular value)
#     Estimated rank (mag): 99
#     MAG: rank 99 computed from 102 data channels with 3 projectors
#     Created an SSP operator (subspace dimension = 3)
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 102 -> 99
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 2201
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 2.1e-14 (2.2e-16 eps * 102 dim * 0.94  max singular value)
#     Estimated rank (mag): 99
#     MAG: rank 99 computed from 102 data channels with 3 projectors
# 7 projection items activated
#     MAG regularization : 0.05
#     Created an SSP operator (subspace dimension = 3)
# Computing rank from covariance with rank={'mag': 99}
#     Setting small MAG eigenvalues to zero (without PCA)
# Computing rank from data with rank=None
#     Using tolerance 1.1e-09 (2.2e-16 eps * 102 dim * 4.9e+04  max singular value)
#     Estimated rank (mag): 99
#     MAG: rank 99 computed from 102 data channels with 3 projectors
#     Created an SSP operator (subspace dimension = 3)
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 102 -> 99
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 1278
# [done]
# Reading forward solution from C:\Users\Dedu\mne_data\MNE-sample-data\MEG\sample\sample_audvis-meg-vol-7-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523) not available
#     Read MEG forward solution (3757 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Computing rank from covariance with rank='info'
#     MAG: rank 99 after 3 projectors applied to 102 channels
# Computing rank from covariance with rank='info'
#     MAG: rank 99 after 3 projectors applied to 102 channels
# Making LCMV beamformer with rank {'mag': 99}
# Computing inverse operator with 102 channels.
#     102 out of 306 channels remain after picking
# Selected 102 channels
# Whitening the forward solution.
#     Created an SSP operator (subspace dimension = 3)
# Computing rank from covariance with rank={'mag': 99}
#     Setting small MAG eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 3757 sources
# Filter computation complete
# C:\Users\Dedu\AppData\Local\Temp\ipykernel_11732\865686596.py:23: RuntimeWarning: This filename (lcmv.nii.gz) does not conform to MNE naming conventions. All LCMV files should end with  or -lcmv.h5
#   stc.save('lcmv.nii.gz', overwrite=True)
